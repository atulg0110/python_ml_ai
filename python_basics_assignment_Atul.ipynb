# %% [markdown]
# <a href="https://colab.research.google.com/github/atulg0110/python_ml_ai/blob/feature%2Fpython_sidebranch/python_basics_assignment_Atul.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Question 1: Print & Variables
Create variables for:
    • Your name

    • Your age

    • Your favorite number

Print each value on a new line using the print statement. '''

#Variable creation
name ="Atul Kumar"
age = 32
fav_num=7

#Printing values
print(name)
print(age)
print(fav_num)

#add new line in between
print()

#value with variable name
print("Name ",name)
print(f"Printing age in format : {age}")
print(f"Favourite number {fav_num}")

# %%
'''Question 2: Arithmetic Operations
Create two variables:
a = 20
b = 6

Using arithmetic operators, print:
    • Sum of a and b

    • Difference of a and b

    • Product of a and b

    • Division result of a by b

Concepts covered:
 Arithmetic operators
'''

a = 20
b = 6

#Sum
print(f"printing sum of a + b = {a+b}")

#product
print(f"printing mul of a * b = {a*b}")

#division
print(f"printing div of a / b = {a/b}")

#floor div means round off result
print(f"printing floor div of a//b = {a//b}")

#mod remainder
print(f"printing mod  of a%b = {a%b}")

# %%
'''Question 3: Relational Operators
Create two variables:
x = 15
y = 10

Print the result of the following comparisons:
    • x > y

    • x < y

    • x == y

    • x != y

Concepts covered:
 Relational operators'''

x=15
y=10

#greater than
print(f"x>y = {x>y}")
#less than
print(f"x<y = {x<y}")
#comparision
print(f"x==y = {x==y}")
#not equsls to
print(f"x!=y = {x!=y}")

# %%
'''Question 4: Logical Operators
Create the following variables:
math_score = 70
science_score = 65
passing_marks = 60

Print:
    1. Whether both subjects are passed (use AND)

    2. Whether at least one subject is passed (use OR)
'''

math_scores=70
science_scores=65
passing_marks=60

# case 1 consider 60 is also passed
final_result = math_scores>=60 and science_scores>=60
print(f"Both subject is result : {final_result}")

# case 2 check OR for atleast one subject
final_result =  math_scores>=60 or science_scores>=60
print(f"Atleast one subject passed for OR case : {final_result}")
# Out:
# Both subject is result : True
# Atleast one subject passed for OR case : True

# %%
'''Question 5: List & Operators
    1. Create a list called marks containing 5 numbers

    2. Print the list

    3. Create a variable total_marks by adding the first two values of the list

    4. Check if total_marks is greater than 100 and print the result
'''

#point 1
marks = [10,30,20,25,70]

#point 2
print(f"printing list values: {marks}")

#point 3
total_marks  = marks[0] +marks[1] + marks[2] + marks[3]+ marks[4]
print(f"printing total_marks : {total_marks}")

#point 4
if total_marks>100:
  print("total_marks is greater than  100")
else :
  print("total marks is not 100")
# Out:
# printing list values: [10, 30, 20, 25, 70]
# printing total_marks : 155
# total_marks is greater than  100
